# %% [markdown]
# #### JTS_base

# %%
base = {

    'rC' : 0.2,  
    'αCT': 0.25,
    'μC' : 0.06,  
    'rM' : 0.3,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    'sB'  : 0.26,      #recalculate using more fish? you don't expect much to change, tho - but it might
    'hB'  : 0.15,      #product of maximum grazing pressure and maximum grazing rate
    'ηB'  : 1,         #Leemput et al., 2016
    'eB'  : 0.02,      #Cook et al., 2024
    'σB'  : 0.6,       #Leemput et al., 2016
    'θB'  : 0,
    'γB'  : 0,
    'μB'  : 0,         #come up with better mortality rate 

    'sG'  : 0.44,
    'hG'  : 15,
    'ηG'  : 1,
    'eG'  : 0.02,
    'σG'  : 0.6,
    'θG'  : 0,
    'γG'  : 0,
    'μG'  : 0,         

    'sS'  : 0.58,      
    'hS'  : 15,      
    'ηS'  : 1,         
    'eS'  : 0.02,      
    'σS'  : 0.6,       
    'θS'  : 0,
    'γS'  : 0,
    'μS'  : 0, 

}

# %% [markdown]
# #### JTS_benthos

# %%
NUTR_benthos = {

    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.7,   #0.35*2 due to effect of nutrification
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 22,    #11*2 due to effect of nutrification

}


SED_benthos = {

    'rC' : 0.15,  #0.2 decreased by 25% due to sedimentation
    'αCT': 0.25,
    'μC' : 0.12,  #0.06*2 due to sedimentation
    'rM' : 0.3,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

}


SED_NUTR_benthos = {

    'rC' : 0.15,  #0.2 decreased by 25% due to sedimentation
    'αCT': 0.25,  #I selected this value over 0.2 because aCT is more likely to be affected by sediments
    'μC' : 0.12,  #0.06*2 due to sedimentation
    'rM' : 0.7,   #0.35*2 due to effect of nutrification
    'αMT': 0.9,
    'αMC': 0.1,   #I selected this value over 0.01 because αMC is more likely to be affected by nutrients (I think)
    'rT' : 22,    #11*2 due to effect of nutrification
    
}

pristine_benthos = {

    'rC' : 0.7,       #all of these are set to the mid range of their pristine values
    'αCT': 0.5,
    'μC' : 0.06,
    'rM' : 0.225,
    'αMT': 0.45,
    'αMC': 0.45,
    'rT' : 11,

}

# %% [markdown]
# #### JTS_herbivores

# %%
herbivore_dictionary = {

    'sB'  : 0.26,      #recalculate using more fish? you don't expect much to change, tho - but it might
    'hB'  : 0.15,      #product of maximum grazing pressure and maximum grazing rate
    'ηB'  : 1,         #Leemput et al., 2016
    'eB'  : 0.02,      #Cook et al., 2024
    'σB'  : 0.6,       #Leemput et al., 2016
    'θB'  : 0,
    'γB'  : 0,
    'μB'  : 0,         #come up with better mortality rate 

    'sG'  : 0.44,
    'hG'  : 15,
    'ηG'  : 1,
    'eG'  : 0.02,
    'σG'  : 0.6,
    'θG'  : 0,
    'γG'  : 0,
    'μG'  : 0,         

    'sS'  : 0.58,      
    'hS'  : 15,      
    'ηS'  : 1,         
    'eS'  : 0.02,      
    'σS'  : 0.6,       
    'θS'  : 0,
    'γS'  : 0,
    'μS'  : 0, 

}
