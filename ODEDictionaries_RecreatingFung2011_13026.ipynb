# %% [markdown]
# #### Deconstructing Fung et al., 2011 Dictionaries
#
# [Fung et al., 2011 CTMm ODE System](#Fung-et-al.,-2011-CTMm-ODE-System)
#
# [Fung et al., 2011 CTMm ODE System without recruitment terms](#Fung-et-al.,-2011-CTMm-ODE-System-without-recruitment)
#
# [Fung et al., 2011 CTMm ODE System without (1) recruitment and (2) macroalgae inhibition of coral growth terms](#Fung-et-al.,-2011-CTMm-ODE-System-without-(1)-recruitment-and-(2)-macroalgae-inhibition-of-coral-growth)
#
# [Fung et al., 2011 CTMm ODE System without (1) recruitment, (2) macroalgae inhibition of coral growth, and (3) grazing pressure](#Fung-et-al.,-2011-CTMm-ODE-System-without-(1)-recruitment,-(2)-macroalgae-inhibition-of-coral-growth,-and-(3)-grazing-pressure)
#
# #### Building Snyder Model Dictionaries
# Benthos: [JTS_benthos](#JTS_benthos)
#
# Browser: [JTS_browser](#JTS_browser)
#
# Grazer: [JTS_grazer](#JTS_grazer)
#
# Scraper: [JTS_scraper](#JTS_scraper)
#
# Experiments
#
# [Experiments_Browser_NUTR](#Experiments_Browser_NUTR)
#
# [Experiments_Browser_SED](#Experiments_Browser_SED)
#
# [Experiments_Grazer_NUTR](#Experiments_Grazer_NUTR)
#
# [Experiments_Grazer_SED](#Experiments_Grazer_SED)
#
# [Experiments_Scraper_NUTR](#Experiments_Scraper_NUTR)
#
# [Experiments_Scraper_SED](#Experiments_Scraper_SED)

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System

# %%
Fung_NUTR_d = {

    #benthos
    'lCs': 0.00006,
    'lCb': 0.0009, 
    'εC' : 0.05,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0.9,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0.6

} 


Fung_SED_d = {

    #benthos
    'lCs': 0.00006,
    'lCb': 0.01, 
    'εC' : 0.05,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0.82,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0.9

}

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System without recruitment

# %%
Fung_NUTR_norec_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0.9,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0.6
    
} 

Fung_SED_norec_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0.82,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0.9
   
}

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System without (1) recruitment and (2) macroalgae inhibition of coral growth

# %%
Fung_NUTR_noinh_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0.6

} 

Fung_SED_noinh_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0.9     
    
}

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System without (1) recruitment, (2) macroalgae inhibition of coral growth, and (3) grazing pressure

# %%
Fung_NUTR_nogp_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0  
    
}

Fung_SED_nogp_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0   
    
}

# %% [markdown]
# #### JTS_benthos

# %%
NUTR_benthos = {

    #benthos
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

}


SED_benthos = {

    #benthos
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

}

# %% [markdown]
# #### JTS_browser

# %%
B_d = {
    
    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0,      #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer

# %%
G_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0,      #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper

# %%
S_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0,      #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### Experiments_Browser_NUTR

# %%
import numpy as np

experiments_B_NUTR = [
    dict(test_param_name     = 'h',
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

        ),
    
    dict(test_param_name    = 'e',
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

         ),
    
    dict(test_param_name    = 'η',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param_name    = 'μ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param_name    = 'θ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param_name    = 'γ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param_name    = 'φ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = B_d

         ),
]

# %% [markdown]
# #### Experiments_Browser_SED

# %%
experiments_B_SED = [
    dict(test_param          = 'h', 
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

        ),
    
    dict(test_param         = 'e', 
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

         ),
    
    dict(test_param         = 'η', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param         = 'μ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param         = 'θ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param         = 'γ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

         ),

    dict(test_param         = 'φ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = B_d

         ),
]

# %% [markdown]
# #### Experiments_Grazer_NUTR

# %%
experiments_G_NUTR = [
    dict(test_param_name     = 'h',
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

        ),
    
    dict(test_param_name    = 'e',
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

         ),
    
    dict(test_param_name    = 'η',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param_name    = 'μ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param_name    = 'θ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param_name    = 'γ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param_name    = 'φ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = G_d

         ),
]

# %% [markdown]
# #### Experiments_Grazer_SED

# %%
experiments_G_SED = [
    dict(test_param          = 'h', 
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

        ),
    
    dict(test_param         = 'e', 
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

         ),
    
    dict(test_param         = 'η', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param         = 'μ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param         = 'θ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

         ),


    dict(test_param         = 'γ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

         ),

    dict(test_param         = 'φ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = G_d

         ),
]

# %% [markdown]
# #### Experiments_Scraper_NUTR

# %%
experiments_S_NUTR = [
    dict(test_param_name     = 'h',
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

        ),
    
    dict(test_param_name    = 'e',
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

         ),
    
    dict(test_param_name    = 'η',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param_name    = 'μ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param_name    = 'θ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param_name    = 'γ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param_name    = 'φ',
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'rM',
         xparam_array        = np.linspace(0.05, 0.4, 21),
         benthos_dictionary  = NUTR_benthos,
         herb_dictionary     = S_d

         ),
]

# %% [markdown]
# #### Experiments_Scraper_SED

# %%
experiments_S_SED = [
    dict(test_param          = 'h', 
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

        ),
    
    dict(test_param         = 'e', 
         test_param_array    = np.linspace(0, 0.2, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

         ),
    
    dict(test_param         = 'η', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param         = 'μ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param         = 'θ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param         = 'γ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

         ),

    dict(test_param         = 'φ', 
         test_param_array    = np.linspace(0, 1, 21),
         xparam_name         = 'μC',
         xparam_array        = np.linspace(0.02, 0.3, 21),
         benthos_dictionary  = SED_benthos,
         herb_dictionary     = S_d

         ),
]
