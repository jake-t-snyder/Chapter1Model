# %% [markdown]
# #### Deconstructing Fung et al., 2011 Dictionaries
#
# [Fung et al., 2011 CTMm ODE System](#Fung-et-al.,-2011-CTMm-ODE-System)
#
# [Fung et al., 2011 CTMm ODE System without recruitment terms](#Fung-et-al.,-2011-CTMm-ODE-System-without-recruitment)
#
# [Fung et al., 2011 CTMm ODE System without (1) recruitment and (2) macroalgae inhibition of coral growth terms](#Fung-et-al.,-2011-CTMm-ODE-System-without-(1)-recruitment-and-(2)-macroalgae-inhibition-of-coral-growth)
#
# [Fung et al., 2011 CTMm ODE System without (1) recruitment, (2) macroalgae inhibition of coral growth, and (3) grazing pressure](#Fung-et-al.,-2011-CTMm-ODE-System-without-(1)-recruitment,-(2)-macroalgae-inhibition-of-coral-growth,-and-(3)-grazing-pressure)
#
# #### Building Snyder Model Dictionaries
# Benthos
#
# [JTS_benthos](#JTS_benthos)
#
# Browser
#
# [JTS_browser herbivory](#JTS_browser-herbivory)
#
# [JTS_browser conversion efficiency](#JTS_browser-conversion-efficiency)
#
# [JTS_browser handling time](#JTS_browser-handling-time)
#
# [JTS_browser mortality](#JTS_browser-mortality)
#
# [JTS_browser immigration](#JTS_browser-immigration)
#
# [JTS_browser emigration](#JTS_browser-emigration)
#
# [JTS_browser recruitment](#JTS_browser-recruitment)
#
# Grazer
#
# [JTS_grazer herbivory](#JTS_grazer-herbivory)
#
# [JTS_grazer conversion efficiency](#JTS_grazer-conversion-efficiency)
#
# [JTS_grazer handling time](#JTS_grazer-handling-time)
#
# [JTS_grazer mortality](#JTS_grazer-mortality)
#
# [JTS_grazer immigration](#JTS_grazer-immigration)
#
# [JTS_grazer emigration](#JTS_grazer-emigration)
#
# [JTS_grazer recruitment](#JTS_grazer-recruitment)
#
# Scraper
#
# [JTS_scraper herbivory](#JTS_scraper-herbivory)
#
# [JTS_scraper conversion efficiency](#JTS_scraper-conversion-efficiency)
#
# [JTS_scraper handling time](#JTS_scraper-handling-time)
#
# [JTS_scraper mortality](#JTS_scraper-mortality)
#
# [JTS_scraper immigration](#JTS_scraper-immigration)
#
# [JTS_scraper emigration](#JTS_scraper-emigration)
#
# [JTS_scraper recruitment](#JTS_scraper-recruitment)
#
# Experiments
#
# [Experiments_Browser_NUTR](#Experiments_Browser_NUTR)
#
# [Experiments_Browser_SED](#Experiments_Browser_SED)
#
# [Experiments_Grazer_NUTR](#Experiments_Grazer_NUTR)
#
# [Experiments_Grazer_SED](#Experiments_Grazer_SED)
#
# [Experiments_Scraper_NUTR](#Experiments_Scraper_NUTR)
#
# [Experiments_Scraper_SED](#Experiments_Scraper_SED)

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System

# %%
Fung_NUTR_d = {

    #benthos
    'lCs': 0.00006,
    'lCb': 0.0009, 
    'εC' : 0.05,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0.9,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0.6

} 


Fung_SED_d = {

    #benthos
    'lCs': 0.00006,
    'lCb': 0.01, 
    'εC' : 0.05,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0.82,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0.9

}

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System without recruitment

# %%
Fung_NUTR_norec_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0.9,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0.6
    
} 

Fung_SED_norec_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0.82,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0.9
   
}

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System without (1) recruitment and (2) macroalgae inhibition of coral growth

# %%
Fung_NUTR_noinh_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0.6

} 

Fung_SED_noinh_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0.9     
    
}

# %% [markdown]
# #### Fung et al., 2011 CTMm ODE System without (1) recruitment, (2) macroalgae inhibition of coral growth, and (3) grazing pressure

# %%
Fung_NUTR_nogp_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

    #herbivores
    'gT' : 9,
    'gM' : 0.5,
    'θ'  : 0  
    
}

Fung_SED_nogp_d = {

    #benthos
    'lCs': 0,
    'lCb': 0, 
    'εC' : 0,
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'βM' : 0,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

    #herbivores
    'gT' : 5,
    'gM' : 0.2,
    'θ'  : 0   
    
}

# %% [markdown]
# #### JTS_benthos

# %%
NUTR_benthos = {

    #benthos
    'rC' : 0.2,
    'αCT': 0.2,
    'μC' : 0.05,
    'rM' : 0.35,
    'αMT': 0.9,
    'αMC': 0.1,
    'rT' : 11,

}


SED_benthos = {

    #benthos
    'rC' : 0.2,
    'αCT': 0.25,
    'μC' : 0.06,
    'rM' : 0.3,
    'αMT': 0.9,
    'αMC': 0.01,
    'rT' : 10,

}

# %% [markdown]
# #### JTS_browser herbivory

# %%
B_NUTR_herb_d = {
    
    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0,      #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_herb_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_browser conversion efficiency

# %%
B_NUTR_conv_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0.3,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_conv_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0.3,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_browser handling time

# %%
B_NUTR_hand_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0.3,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,     #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_hand_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0.3,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_browser mortality

# %%
B_NUTR_mort_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0.3,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_mort_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0.3,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_browser immigration

# %%
B_NUTR_imm_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0.3,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_imm_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0.3,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_browser emigration

# %%
B_NUTR_em_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0.3,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_em_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0.3,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_browser recruitment

# %%
B_NUTR_rec_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0.3,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

B_SED_rec_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0.3,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer herbivory

# %%
G_NUTR_herb_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0,      #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_herb_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer conversion efficieny

# %%
G_NUTR_conv_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_conv_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer handling time

# %%
G_NUTR_hand_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_hand_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer mortality

# %%
G_NUTR_mort_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_mort_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer immigration

# %%
G_NUTR_imm_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_imm_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer emigration

# %%
G_NUTR_em_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_em_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_grazer recruitment

# %%
G_NUTR_rec_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

G_SED_rec_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper herbivory

# %%
S_NUTR_herb_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 0,      #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_herb_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 0,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper conversion efficiency

# %%
S_NUTR_conv_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_conv_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper handling time

# %%
S_NUTR_hand_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_hand_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper mortality

# %%
S_NUTR_mort_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_mort_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper immigration

# %%
S_NUTR_imm_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_imm_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper emigration

# %%
S_NUTR_em_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_em_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### JTS_scraper recruitment

# %%
S_NUTR_rec_d = {

    #herbivores
    's'  : 0.12,   #recalculate using more fish? you don't except much to change, tho - but it might
    'h'  : 5.4,    #your "h" value is the product of Fung's gT/gM and theta values
    'η'  : 0,
    'e'  : 1,      #this is from Cook et al., 2024
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

S_SED_rec_d = {

    #herbivores
    's'  : 0.12,
    'h'  : 5.4,
    'η'  : 0,
    'e'  : 1,
    'μ'  : 0,
    'θ'  : 0,
    'γ'  : 0,
    'φ'  : 0
    
}

# %% [markdown]
# #### Experiments_Browser_NUTR

# %%
import numpy as np

experiments_B_NUTR = [
    dict(test_param = 'h', 
         herb_dictionary = B_NUTR_herb_d, 
         test_param_val = np.linspace(0, 0.2, 21),

        ),
    
     dict(test_param = 'e', 
         herb_dictionary = B_NUTR_conv_d, 
         test_param_val = np.linspace(0, 0.2, 21),

         ),
    
     dict(test_param = 'η', 
         herb_dictionary = B_NUTR_hand_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'd', 
         herb_dictionary = B_NUTR_mort_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'θ', 
         herb_dictionary = B_NUTR_imm_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'γ', 
         herb_dictionary = B_NUTR_em_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'φ', 
         herb_dictionary = B_NUTR_rec_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),
]

# %% [markdown]
# #### Experiments_Browser_SED

# %%
experiments_B_SED = [
    dict(test_param = 'h', 
         herb_dictionary = B_SED_herb_d, 
         test_param_val = np.linspace(0, 0.2, 21),

        ),
    
     dict(test_param = 'e', 
         herb_dictionary = B_SED_conv_d, 
         test_param_val = np.linspace(0, 0.2, 21),

         ),
    
     dict(test_param = 'η', 
         herb_dictionary = B_SED_hand_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'd', 
         herb_dictionary = B_SED_mort_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'θ', 
         herb_dictionary = B_SED_imm_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'γ', 
         herb_dictionary = B_SED_em_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'φ', 
         herb_dictionary = B_SED_rec_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),
]

# %% [markdown]
# #### Experiments_Grazer_NUTR

# %%
experiments_G_NUTR = [
    dict(test_param = 'h', 
         herb_dictionary = G_NUTR_herb_d, 
         test_param_val = np.linspace(0, 20, 21),

        ),
    
     dict(test_param = 'e', 
         herb_dictionary = G_NUTR_conv_d, 
         test_param_val = np.linspace(0, 0.2, 21),

         ),
    
     dict(test_param = 'η', 
         herb_dictionary = G_NUTR_hand_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'd', 
         herb_dictionary = G_NUTR_mort_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'θ', 
         herb_dictionary = G_NUTR_imm_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'γ', 
         herb_dictionary = G_NUTR_em_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'φ', 
         herb_dictionary = G_NUTR_rec_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),
]

# %% [markdown]
# #### Experiments_Grazer_SED

# %%
experiments_G_SED = [
    dict(test_param = 'h', 
         herb_dictionary = G_SED_herb_d, 
         test_param_val = np.linspace(0, 20, 21),

        ),
    
     dict(test_param = 'e', 
         herb_dictionary = G_SED_conv_d, 
         test_param_val = np.linspace(0, 0.2, 21),

         ),
    
     dict(test_param = 'η', 
         herb_dictionary = G_SED_hand_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'd', 
         herb_dictionary = G_SED_mort_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'θ', 
         herb_dictionary = G_SED_imm_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'γ', 
         herb_dictionary = G_SED_em_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'φ', 
         herb_dictionary = G_SED_rec_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),
]

# %% [markdown]
# #### Experiments_Scraper_NUTR

# %%
experiments_S_NUTR = [
    dict(test_param = 'h', 
         herb_dictionary = S_NUTR_herb_d, 
         test_param_val = np.linspace(0, 20, 21),

        ),
    
     dict(test_param = 'e', 
         herb_dictionary = S_NUTR_conv_d, 
         test_param_val = np.linspace(0, 0.2, 21),

         ),
    
     dict(test_param = 'η', 
         herb_dictionary = S_NUTR_hand_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'd', 
         herb_dictionary = S_NUTR_mort_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'θ', 
         herb_dictionary = S_NUTR_imm_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'γ', 
         herb_dictionary = S_NUTR_em_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'φ', 
         herb_dictionary = S_NUTR_rec_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),
]

# %% [markdown]
# #### Experiments_Scraper_SED

# %%
experiments_S_SED = [
    dict(test_param = 'h', 
         herb_dictionary = S_SED_herb_d, 
         test_param_val = np.linspace(0, 20, 21),

        ),
    
     dict(test_param = 'e', 
         herb_dictionary = S_SED_conv_d, 
         test_param_val = np.linspace(0, 0.2, 21),

         ),
    
     dict(test_param = 'η', 
         herb_dictionary = S_SED_hand_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'd', 
         herb_dictionary = S_SED_mort_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'θ', 
         herb_dictionary = S_SED_imm_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'γ', 
         herb_dictionary = S_SED_em_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),

     dict(test_param = 'φ', 
         herb_dictionary = S_SED_rec_d, 
         test_param_val = np.linspace(0, 1, 21),

         ),
]
